# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
#pip install geoviews
import hvplot.pandas
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
import json
#import gmaps
#import os
#import time
#import gmaps.datasets



# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_csv =  "output_data/cities.csv"

# Display sample data
city_data_df = pd.read_csv(city_data_csv)
city_data_df.head()
# Out:
#    City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 0        0        i-n-salah  27.1935    2.4607     83.19        28
# 1        1           albany  42.6001  -73.9662     57.81        93
# 2        2     invercargill -46.4000  168.3500     47.01        79
# 3        3          dudinka  69.4058   86.1778     25.63        89
# 4        4  remire-montjoly   4.9167  -52.2667     80.64        89
#
#    Cloudiness  Wind Speed Country        Date
# 0           0       25.03      DZ  1696035890
# 1         100        1.16      US  1696035848
# 2         100       21.00      NZ  1696035890
# 3         100       19.75      RU  1696035890
# 4           0        3.44      GF  1696035890

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
#config(api_keys=geoapify_key)
map_plot = city_data_df.hvplot.points('Lng', 'Lat', geo=True, color='City', alpha=0.5,
                       size = "Humidity", tiles='OSM')
# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
cloud_cond = (city_data_df["Cloudiness"] == 0)
cloud_df = city_data_df.loc[cloud_cond]

# Drop any rows with null values
wind_df = cloud_df.dropna()
wind_df

# Display sample data
# YOUR CODE HERE
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 0          0                    i-n-salah  27.1935    2.4607     83.19
# 4          4              remire-montjoly   4.9167  -52.2667     80.64
# 12        12                  as sulayyil  20.4607   45.5779     77.25
# 19        19                      ushuaia -54.8000  -68.3000     49.66
# 37        37                    yebaishou  41.3975  119.6408     61.88
# ..       ...                          ...      ...       ...       ...
# 570      570                       mahdia  35.5047   11.0622     75.15
# 577      577                         duba  27.3513   35.6901     91.04
# 579      579                       dammam  26.4344   50.1033     80.71
# 582      582                    fortaleza  -3.7227  -38.5247     80.22
# 585      585  istgah-e rah ahan-e garmsar  35.2346   52.3094     67.59
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = cloud_df[["City","Country","Lat","Lng","Humidity"]].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Nmae"] = ""

# Display sample data
hotel_df
# Out:
#                             City Country      Lat       Lng  Humidity  \
# 0                      i-n-salah      DZ  27.1935    2.4607        28
# 4                remire-montjoly      GF   4.9167  -52.2667        89
# 12                   as sulayyil      SA  20.4607   45.5779        17
# 19                       ushuaia      AR -54.8000  -68.3000        43
# 37                     yebaishou      CN  41.3975  119.6408        34
# ..                           ...     ...      ...       ...       ...
# 577                         duba      SA  27.3513   35.6901        28
# 578                   walvis bay     NaN -22.9575   14.5053        93
# 579                       dammam      SA  26.4344   50.1033        94
# 582                    fortaleza      BR  -3.7227  -38.5247        78
# 585  istgah-e rah ahan-e garmsar      IR  35.2346   52.3094        28
#
#     Hotel Nmae
# 0
# 4
# 12
# 19
# 37
# ..         ...
# 577
# 578
# 579
# 582
# 585
#
# [90 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
https://api.geoapify.com/v2/places?categories=accommodation.hotel&filter=circle:140.6833,41.8833,10000&bias=proximity:140.6833,41.88338&limit=20&apiKey=d548c5ed24604be6a9dd0d989631f783
# Out:
#   Cell In[17], line 1
#     https://api.geoapify.com/v2/places?categories=accommodation.hotel&filter=circle:140.6833,41.8833,10000&bias=proximity:140.6833,41.88338&limit=20&apiKey=d548c5ed24604be6a9dd0d989631f783
#           ^
# SyntaxError: invalid syntax

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    
     "categories":"accommodation.hotel",
    "limit":20,
    "apiKey":geoapify_key
    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
   
    


    # Make and API request using the params dictionaty
    name_address =  requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# i-n-salah - nearest hotel: باجودة
# remire-montjoly - nearest hotel: Complexe Belova
# as sulayyil - nearest hotel: No hotel found
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# yebaishou - nearest hotel: No hotel found
# mohr - nearest hotel: Hotel Heidehof
# laojunmiao - nearest hotel: No hotel found
# minot - nearest hotel: Hampton Inn & Suites
# talcahuano - nearest hotel: Club Recreativo Armada de Chile
# cinisi - nearest hotel: Cinisi Vacanze
# kerman - nearest hotel: حافظ
# tsiombe - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# kenai - nearest hotel: Beluga Lookout Hotel
# mount isa - nearest hotel: Ibis Styles
# mersa matruh - nearest hotel: صقور
# punta arenas - nearest hotel: Hotel Lacolet
# aswan - nearest hotel: Yaseen hotel
# stanley - nearest hotel: Hotel 52
# pachino - nearest hotel: Hotel Celeste
# port elizabeth - nearest hotel: Waterford Hotel
# prince rupert - nearest hotel: Crest Hotel
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
