# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
#output city file

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print('-'*25)

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | i-n-salah
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | invercargill
# Processing Record 4 of Set 1 | dudinka
# Processing Record 5 of Set 1 | remire-montjoly
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | ilulissat
# Processing Record 8 of Set 1 | rio grande
# Processing Record 9 of Set 1 | port mathurin
# Processing Record 10 of Set 1 | laascaanood
# Processing Record 11 of Set 1 | corbelia
# Processing Record 12 of Set 1 | badger
# Processing Record 13 of Set 1 | as sulayyil
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | al majaridah
# Processing Record 16 of Set 1 | margaret river
# Processing Record 17 of Set 1 | arteche
# Processing Record 18 of Set 1 | martapura
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | tanjung selor
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | grytviken
# Processing Record 25 of Set 1 | anadyr
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | sao tome
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | castillos
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | greymouth
# Processing Record 32 of Set 1 | sinabang
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | sao gabriel da cachoeira
# Processing Record 35 of Set 1 | tazovsky
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | pingliang
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | yebaishou
# Processing Record 40 of Set 1 | gereida
# Processing Record 41 of Set 1 | yanjiang
# Processing Record 42 of Set 1 | orsa
# Processing Record 43 of Set 1 | waitangi
# Processing Record 44 of Set 1 | kataragama
# City not found. Skipping...
# Processing Record 45 of Set 1 | huarmey
# Processing Record 46 of Set 1 | vikulovo
# Processing Record 47 of Set 1 | mohr
# Processing Record 48 of Set 1 | luwuk
# Processing Record 49 of Set 1 | pontes e lacerda
# Processing Record 50 of Set 1 | kodiak
# Processing Record 0 of Set 2 | puerto natales
# Processing Record 1 of Set 2 | nova sintra
# Processing Record 2 of Set 2 | haiku-pauwela
# Processing Record 3 of Set 2 | oranjemund
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | laojunmiao
# Processing Record 6 of Set 2 | chust
# Processing Record 7 of Set 2 | minot
# Processing Record 8 of Set 2 | talcahuano
# Processing Record 9 of Set 2 | lagoa
# Processing Record 10 of Set 2 | akureyri
# Processing Record 11 of Set 2 | vorgashor
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | rongelap
# Processing Record 14 of Set 2 | kirensk
# Processing Record 15 of Set 2 | el daein
# City not found. Skipping...
# Processing Record 16 of Set 2 | vilyuchinsk
# Processing Record 17 of Set 2 | kingsford
# Processing Record 18 of Set 2 | whitehorse
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | choibalsan
# Processing Record 21 of Set 2 | cinisi
# Processing Record 22 of Set 2 | kerman
# Processing Record 23 of Set 2 | utrik
# Processing Record 24 of Set 2 | dapa
# Processing Record 25 of Set 2 | yellowknife
# Processing Record 26 of Set 2 | northam
# Processing Record 27 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 28 of Set 2 | portland
# Processing Record 29 of Set 2 | kapoeta
# Processing Record 30 of Set 2 | olonkinbyen
# Processing Record 31 of Set 2 | enewetak
# Processing Record 32 of Set 2 | newman
# Processing Record 33 of Set 2 | lhasa
# Processing Record 34 of Set 2 | funafuti
# Processing Record 35 of Set 2 | ola
# Processing Record 36 of Set 2 | tsiombe
# Processing Record 37 of Set 2 | san patricio
# Processing Record 38 of Set 2 | tevragh zeina
# City not found. Skipping...
# Processing Record 39 of Set 2 | chui
# Processing Record 40 of Set 2 | margate
# Processing Record 41 of Set 2 | isafjordur
# Processing Record 42 of Set 2 | porto novo
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | udachny
# Processing Record 46 of Set 2 | tosontsengel
# Processing Record 47 of Set 2 | kenai
# Processing Record 48 of Set 2 | edinburgh of the seven seas
# Processing Record 49 of Set 2 | isle of lewis
# City not found. Skipping...
# Processing Record 0 of Set 3 | kavaratti
# Processing Record 1 of Set 3 | west island
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | kronstadt
# Processing Record 4 of Set 3 | kingston
# Processing Record 5 of Set 3 | freetown
# Processing Record 6 of Set 3 | linfen
# Processing Record 7 of Set 3 | sheregesh
# Processing Record 8 of Set 3 | burang
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | antigonish
# Processing Record 11 of Set 3 | mount isa
# Processing Record 12 of Set 3 | mersa matruh
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | aswan
# Processing Record 15 of Set 3 | stanley
# Processing Record 16 of Set 3 | blackmans bay
# Processing Record 17 of Set 3 | sao vicente
# Processing Record 18 of Set 3 | wailua homesteads
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | singa
# Processing Record 21 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 3 | pachino
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | christchurch
# Processing Record 25 of Set 3 | glasgow
# Processing Record 26 of Set 3 | richards bay
# Processing Record 27 of Set 3 | vernon
# Processing Record 28 of Set 3 | argo
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | ripky
# Processing Record 31 of Set 3 | katsuren-haebaru
# Processing Record 32 of Set 3 | kasempa
# Processing Record 33 of Set 3 | conceicao da barra
# Processing Record 34 of Set 3 | college
# Processing Record 35 of Set 3 | minas de marcona
# Processing Record 36 of Set 3 | crane
# Processing Record 37 of Set 3 | vila franca do campo
# Processing Record 38 of Set 3 | tamanrasset
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | sitka
# Processing Record 41 of Set 3 | tidjikja
# Processing Record 42 of Set 3 | prince rupert
# Processing Record 43 of Set 3 | tibro
# Processing Record 44 of Set 3 | stayton
# Processing Record 45 of Set 3 | bataipora
# Processing Record 46 of Set 3 | brady
# Processing Record 47 of Set 3 | saint-joseph
# Processing Record 48 of Set 3 | churapcha
# Processing Record 49 of Set 3 | brookings
# Processing Record 0 of Set 4 | byron bay
# Processing Record 1 of Set 4 | namibe
# Processing Record 2 of Set 4 | hawaiian paradise park
# Processing Record 3 of Set 4 | izluchinsk
# Processing Record 4 of Set 4 | fort bragg
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | antsiranana
# Processing Record 8 of Set 4 | santa helena de goias
# Processing Record 9 of Set 4 | suva
# Processing Record 10 of Set 4 | ust-nera
# Processing Record 11 of Set 4 | karratha
# Processing Record 12 of Set 4 | puerto baquerizo moreno
# Processing Record 13 of Set 4 | beboto
# Processing Record 14 of Set 4 | leava
# Processing Record 15 of Set 4 | mo i rana
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | nizhniy kuranakh
# Processing Record 18 of Set 4 | boa vista
# Processing Record 19 of Set 4 | kailua-kona
# Processing Record 20 of Set 4 | hamilton
# Processing Record 21 of Set 4 | papatowai
# Processing Record 22 of Set 4 | aasiaat
# Processing Record 23 of Set 4 | st. john's
# Processing Record 24 of Set 4 | swakopmund
# Processing Record 25 of Set 4 | tottori
# Processing Record 26 of Set 4 | kendari
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | mount pearl
# Processing Record 29 of Set 4 | ayaguz
# City not found. Skipping...
# Processing Record 30 of Set 4 | papao
# Processing Record 31 of Set 4 | kulhudhuffushi
# Processing Record 32 of Set 4 | marsh harbour
# Processing Record 33 of Set 4 | iskateley
# Processing Record 34 of Set 4 | inarajan village
# Processing Record 35 of Set 4 | saipan
# Processing Record 36 of Set 4 | callao
# Processing Record 37 of Set 4 | puerto carreno
# Processing Record 38 of Set 4 | mont-laurier
# Processing Record 39 of Set 4 | nizhnevartovsk
# Processing Record 40 of Set 4 | la passe
# Processing Record 41 of Set 4 | taro
# Processing Record 42 of Set 4 | cannonvale
# Processing Record 43 of Set 4 | gypsum
# Processing Record 44 of Set 4 | hell-ville
# Processing Record 45 of Set 4 | kyshtovka
# Processing Record 46 of Set 4 | katabu
# Processing Record 47 of Set 4 | kourou
# Processing Record 48 of Set 4 | kapuskasing
# Processing Record 49 of Set 4 | reggane
# Processing Record 0 of Set 5 | aykhal
# Processing Record 1 of Set 5 | coaldale
# Processing Record 2 of Set 5 | singkil
# Processing Record 3 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 4 of Set 5 | bonny
# Processing Record 5 of Set 5 | turpan
# Processing Record 6 of Set 5 | midvagur
# Processing Record 7 of Set 5 | alice springs
# Processing Record 8 of Set 5 | humberto de campos
# Processing Record 9 of Set 5 | quellon
# Processing Record 10 of Set 5 | ta`u
# Processing Record 11 of Set 5 | vallenar
# Processing Record 12 of Set 5 | saguenay
# Processing Record 13 of Set 5 | klyuchi
# Processing Record 14 of Set 5 | queenstown
# Processing Record 15 of Set 5 | fada
# Processing Record 16 of Set 5 | fale old settlement
# Processing Record 17 of Set 5 | antonio enes
# Processing Record 18 of Set 5 | jiagedaqi
# Processing Record 19 of Set 5 | avarua
# Processing Record 20 of Set 5 | lompoc
# Processing Record 21 of Set 5 | kapa'a
# Processing Record 22 of Set 5 | igarka
# Processing Record 23 of Set 5 | mitu
# Processing Record 24 of Set 5 | san clemente
# Processing Record 25 of Set 5 | nouadhibou
# Processing Record 26 of Set 5 | sao jose da coroa grande
# Processing Record 27 of Set 5 | nagqu
# Processing Record 28 of Set 5 | inhambane
# Processing Record 29 of Set 5 | taulaga
# Processing Record 30 of Set 5 | villarrica
# Processing Record 31 of Set 5 | saint-philippe
# Processing Record 32 of Set 5 | hakha
# Processing Record 33 of Set 5 | beidaihehaibin
# Processing Record 34 of Set 5 | san antonio de pale
# Processing Record 35 of Set 5 | bardai
# Processing Record 36 of Set 5 | east ballina
# Processing Record 37 of Set 5 | troitsko-pechorsk
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | kismayo
# Processing Record 40 of Set 5 | porto-vecchio
# Processing Record 41 of Set 5 | nelson bay
# Processing Record 42 of Set 5 | uturoa
# Processing Record 43 of Set 5 | sodra sandby
# Processing Record 44 of Set 5 | el copey
# Processing Record 45 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 46 of Set 5 | aginskoye
# Processing Record 47 of Set 5 | qal'at bishah
# City not found. Skipping...
# Processing Record 48 of Set 5 | yuzhno-kurilsk
# Processing Record 49 of Set 5 | sikonge
# Processing Record 0 of Set 6 | benevento
# Processing Record 1 of Set 6 | cabedelo
# Processing Record 2 of Set 6 | dawei
# Processing Record 3 of Set 6 | goias
# Processing Record 4 of Set 6 | awjilah
# Processing Record 5 of Set 6 | afaahiti
# Processing Record 6 of Set 6 | sao mateus
# Processing Record 7 of Set 6 | alofi
# Processing Record 8 of Set 6 | antofagasta
# Processing Record 9 of Set 6 | talakan
# Processing Record 10 of Set 6 | luderitz
# Processing Record 11 of Set 6 | dalby
# Processing Record 12 of Set 6 | andergrove
# Processing Record 13 of Set 6 | chernyshevskiy
# Processing Record 14 of Set 6 | bubaque
# Processing Record 15 of Set 6 | chimoio
# Processing Record 16 of Set 6 | tolanaro
# Processing Record 17 of Set 6 | jamestown
# Processing Record 18 of Set 6 | thoothukudi
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | zhangjiakou
# Processing Record 21 of Set 6 | keflavik
# Processing Record 22 of Set 6 | ambikapur
# Processing Record 23 of Set 6 | waingapu
# Processing Record 24 of Set 6 | gadzhiyevo
# Processing Record 25 of Set 6 | egilsstadir
# Processing Record 26 of Set 6 | wad medani
# Processing Record 27 of Set 6 | nuuk
# Processing Record 28 of Set 6 | hilo
# Processing Record 29 of Set 6 | leninskoye
# Processing Record 30 of Set 6 | piraju
# Processing Record 31 of Set 6 | lamia
# Processing Record 32 of Set 6 | cova figueira
# Processing Record 33 of Set 6 | susuman
# Processing Record 34 of Set 6 | polyarnyy
# Processing Record 35 of Set 6 | harstad
# Processing Record 36 of Set 6 | pisco
# Processing Record 37 of Set 6 | takamaka
# City not found. Skipping...
# Processing Record 38 of Set 6 | orange cove
# Processing Record 39 of Set 6 | fuglafjordur
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | labrador city
# Processing Record 42 of Set 6 | pathein
# Processing Record 43 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 44 of Set 6 | olyokminsk
# Processing Record 45 of Set 6 | narasapur
# Processing Record 46 of Set 6 | qamdo
# Processing Record 47 of Set 6 | caldwell
# Processing Record 48 of Set 6 | holualoa
# Processing Record 49 of Set 6 | takoradi
# Processing Record 0 of Set 7 | kloulklubed
# Processing Record 1 of Set 7 | novodvinsk
# Processing Record 2 of Set 7 | houthulst
# Processing Record 3 of Set 7 | sinop
# Processing Record 4 of Set 7 | nizhnesortymskiy
# Processing Record 5 of Set 7 | durazno
# Processing Record 6 of Set 7 | yasothon
# Processing Record 7 of Set 7 | beloyarskiy
# Processing Record 8 of Set 7 | novaya igirma
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | magole
# Processing Record 11 of Set 7 | viedma
# Processing Record 12 of Set 7 | serchhip
# Processing Record 13 of Set 7 | muisne
# Processing Record 14 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 15 of Set 7 | yaren
# Processing Record 16 of Set 7 | north bend
# Processing Record 17 of Set 7 | makueni boma
# Processing Record 18 of Set 7 | auki
# Processing Record 19 of Set 7 | vila velha
# Processing Record 20 of Set 7 | sohagpur
# Processing Record 21 of Set 7 | heroica caborca
# Processing Record 22 of Set 7 | touros
# Processing Record 23 of Set 7 | surab
# Processing Record 24 of Set 7 | donaghadee
# Processing Record 25 of Set 7 | lae
# Processing Record 26 of Set 7 | yantarnyy
# Processing Record 27 of Set 7 | khovd
# Processing Record 28 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 29 of Set 7 | san juan
# Processing Record 30 of Set 7 | bima
# Processing Record 31 of Set 7 | carutapera
# Processing Record 32 of Set 7 | zwedru
# Processing Record 33 of Set 7 | veraval
# Processing Record 34 of Set 7 | bouna
# Processing Record 35 of Set 7 | daru
# Processing Record 36 of Set 7 | gornopravdinsk
# Processing Record 37 of Set 7 | sant lluis
# Processing Record 38 of Set 7 | nemuro
# Processing Record 39 of Set 7 | lauro de freitas
# Processing Record 40 of Set 7 | bullhead city
# Processing Record 41 of Set 7 | tamandare
# Processing Record 42 of Set 7 | xining
# Processing Record 43 of Set 7 | fort drum
# Processing Record 44 of Set 7 | kalevala
# Processing Record 45 of Set 7 | bria
# Processing Record 46 of Set 7 | tabou
# Processing Record 47 of Set 7 | sanandaj
# Processing Record 48 of Set 7 | matthew town
# Processing Record 49 of Set 7 | zhangzhou
# Processing Record 0 of Set 8 | oriximina
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | chopan
# Processing Record 3 of Set 8 | sisimiut
# Processing Record 4 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 5 of Set 8 | constantia
# Processing Record 6 of Set 8 | alamosa
# Processing Record 7 of Set 8 | yatou
# Processing Record 8 of Set 8 | sampit
# Processing Record 9 of Set 8 | vilhena
# Processing Record 10 of Set 8 | uaboe
# City not found. Skipping...
# Processing Record 11 of Set 8 | kone
# Processing Record 12 of Set 8 | sonoita
# Processing Record 13 of Set 8 | nioki
# Processing Record 14 of Set 8 | aoulef
# Processing Record 15 of Set 8 | atafu village
# Processing Record 16 of Set 8 | kimhae
# Processing Record 17 of Set 8 | al 'alamayn
# City not found. Skipping...
# Processing Record 18 of Set 8 | carauari
# Processing Record 19 of Set 8 | james island
# City not found. Skipping...
# Processing Record 20 of Set 8 | gunjur
# Processing Record 21 of Set 8 | thomaston
# Processing Record 22 of Set 8 | khirkiyan
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | pudasjarvi
# Processing Record 25 of Set 8 | hotan
# Processing Record 26 of Set 8 | armacao de buzios
# Processing Record 27 of Set 8 | nosy varika
# Processing Record 28 of Set 8 | cabo san lucas
# Processing Record 29 of Set 8 | sept-iles
# Processing Record 30 of Set 8 | bel ombre
# Processing Record 31 of Set 8 | port alfred
# Processing Record 32 of Set 8 | mezhdurechenskiy
# Processing Record 33 of Set 8 | oxelosund
# Processing Record 34 of Set 8 | tayu
# Processing Record 35 of Set 8 | wuxue
# Processing Record 36 of Set 8 | deqen
# Processing Record 37 of Set 8 | nizhniy odes
# Processing Record 38 of Set 8 | oban
# Processing Record 39 of Set 8 | pacasmayo
# Processing Record 40 of Set 8 | tianpeng
# Processing Record 41 of Set 8 | celestun
# Processing Record 42 of Set 8 | pandan
# Processing Record 43 of Set 8 | itaituba
# Processing Record 44 of Set 8 | labe
# Processing Record 45 of Set 8 | svetlyy
# Processing Record 46 of Set 8 | al khums
# Processing Record 47 of Set 8 | bafq
# Processing Record 48 of Set 8 | canals
# Processing Record 49 of Set 8 | fortuna
# Processing Record 0 of Set 9 | kayangel
# Processing Record 1 of Set 9 | weno
# Processing Record 2 of Set 9 | quepos
# Processing Record 3 of Set 9 | dzhangala
# Processing Record 4 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 9 | cruzeiro do sul
# Processing Record 6 of Set 9 | hasaki
# Processing Record 7 of Set 9 | bornu yassu
# Processing Record 8 of Set 9 | acarau
# Processing Record 9 of Set 9 | selfoss
# Processing Record 10 of Set 9 | kerema
# Processing Record 11 of Set 9 | tafuna
# Processing Record 12 of Set 9 | plastun
# Processing Record 13 of Set 9 | mandera
# Processing Record 14 of Set 9 | cibla
# Processing Record 15 of Set 9 | ndele
# Processing Record 16 of Set 9 | senanga
# Processing Record 17 of Set 9 | yeonggwang
# Processing Record 18 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 19 of Set 9 | les sables-d'olonne
# Processing Record 20 of Set 9 | el sauzal de rodriguez
# Processing Record 21 of Set 9 | balabac
# Processing Record 22 of Set 9 | hadibu
# Processing Record 23 of Set 9 | kamaishi
# Processing Record 24 of Set 9 | taoudenni
# Processing Record 25 of Set 9 | malpur
# Processing Record 26 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 27 of Set 9 | batticaloa
# Processing Record 28 of Set 9 | balsas
# Processing Record 29 of Set 9 | broome
# Processing Record 30 of Set 9 | garden city
# Processing Record 31 of Set 9 | al ghayzah
# Processing Record 32 of Set 9 | mil'kovo
# Processing Record 33 of Set 9 | chardara
# Processing Record 34 of Set 9 | jiaojiang
# Processing Record 35 of Set 9 | vadso
# Processing Record 36 of Set 9 | nar'yan-mar
# Processing Record 37 of Set 9 | magadan
# Processing Record 38 of Set 9 | dupnitsa
# Processing Record 39 of Set 9 | durango
# Processing Record 40 of Set 9 | lihue
# Processing Record 41 of Set 9 | n'zeto
# Processing Record 42 of Set 9 | mount gambier
# Processing Record 43 of Set 9 | rajbiraj
# Processing Record 44 of Set 9 | aromashevo
# Processing Record 45 of Set 9 | virginia
# Processing Record 46 of Set 9 | sao desiderio
# Processing Record 47 of Set 9 | chom thong
# Processing Record 48 of Set 9 | ado-odo
# Processing Record 49 of Set 9 | lorengau
# Processing Record 0 of Set 10 | joshimath
# Processing Record 1 of Set 10 | kinmparana
# Processing Record 2 of Set 10 | shklow
# Processing Record 3 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 4 of Set 10 | luanda
# Processing Record 5 of Set 10 | bandipura
# Processing Record 6 of Set 10 | nakamura
# Processing Record 7 of Set 10 | pitea
# Processing Record 8 of Set 10 | salem
# Processing Record 9 of Set 10 | arraial do cabo
# Processing Record 10 of Set 10 | nyrob
# Processing Record 11 of Set 10 | san mariano
# Processing Record 12 of Set 10 | vorkuta
# Processing Record 13 of Set 10 | rey bouba
# Processing Record 14 of Set 10 | simanggang
# Processing Record 15 of Set 10 | sechura
# Processing Record 16 of Set 10 | upington
# Processing Record 17 of Set 10 | gusinoozyorsk
# Processing Record 18 of Set 10 | aldan
# Processing Record 19 of Set 10 | macapa
# Processing Record 20 of Set 10 | banamba
# Processing Record 21 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 22 of Set 10 | santanyi
# Processing Record 23 of Set 10 | champerico
# Processing Record 24 of Set 10 | angaur state
# Processing Record 25 of Set 10 | mazamari
# Processing Record 26 of Set 10 | khandyga
# Processing Record 27 of Set 10 | revda
# Processing Record 28 of Set 10 | zhangye
# Processing Record 29 of Set 10 | ashburton
# Processing Record 30 of Set 10 | kuanda
# Processing Record 31 of Set 10 | prado
# Processing Record 32 of Set 10 | slobodskoy
# Processing Record 33 of Set 10 | new norfolk
# Processing Record 34 of Set 10 | sandnessjoen
# Processing Record 35 of Set 10 | gaspe
# Processing Record 36 of Set 10 | masterton
# Processing Record 37 of Set 10 | kievka
# Processing Record 38 of Set 10 | yarmouth
# Processing Record 39 of Set 10 | luoyang
# Processing Record 40 of Set 10 | tierra nueva
# Processing Record 41 of Set 10 | beyneu
# Processing Record 42 of Set 10 | chibougamau
# Processing Record 43 of Set 10 | rybnaya sloboda
# Processing Record 44 of Set 10 | ancud
# Processing Record 45 of Set 10 | chonchi
# Processing Record 46 of Set 10 | salinopolis
# Processing Record 47 of Set 10 | mezhdurechensk
# Processing Record 48 of Set 10 | mabaruma
# Processing Record 49 of Set 10 | leisure city
# Processing Record 0 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 1 of Set 11 | zhangjiakou shi xuanhua qu
# Processing Record 2 of Set 11 | the bottom
# Processing Record 3 of Set 11 | nyurba
# Processing Record 4 of Set 11 | flying fish cove
# Processing Record 5 of Set 11 | paramonga
# Processing Record 6 of Set 11 | amahai
# Processing Record 7 of Set 11 | nayoro
# Processing Record 8 of Set 11 | opuwo
# Processing Record 9 of Set 11 | happy valley-goose bay
# Processing Record 10 of Set 11 | dunedin
# Processing Record 11 of Set 11 | ulsteinvik
# Processing Record 12 of Set 11 | betio village
# Processing Record 13 of Set 11 | saint-pierre
# Processing Record 14 of Set 11 | vrangel'
# Processing Record 15 of Set 11 | san miguel
# Processing Record 16 of Set 11 | rock springs
# Processing Record 17 of Set 11 | hammerfest
# Processing Record 18 of Set 11 | ketchikan
# Processing Record 19 of Set 11 | rosetta
# Processing Record 20 of Set 11 | marlin
# Processing Record 21 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 22 of Set 11 | mugia
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | malanje
# Processing Record 25 of Set 11 | isangel
# Processing Record 26 of Set 11 | torghay
# Processing Record 27 of Set 11 | mindif
# Processing Record 28 of Set 11 | saurimo
# Processing Record 29 of Set 11 | poronaysk
# Processing Record 30 of Set 11 | el haouaria
# Processing Record 31 of Set 11 | seybaplaya
# Processing Record 32 of Set 11 | saint-francois
# Processing Record 33 of Set 11 | ampanihy
# Processing Record 34 of Set 11 | ostroda
# Processing Record 35 of Set 11 | ljungby
# Processing Record 36 of Set 11 | labytnangi
# Processing Record 37 of Set 11 | manta
# Processing Record 38 of Set 11 | yel'nya
# Processing Record 39 of Set 11 | kansanshi
# Processing Record 40 of Set 11 | fort knox
# Processing Record 41 of Set 11 | balykshi
# Processing Record 42 of Set 11 | gora
# Processing Record 43 of Set 11 | bikenibeu village
# Processing Record 44 of Set 11 | grande prairie
# Processing Record 45 of Set 11 | kidal
# Processing Record 46 of Set 11 | colares
# Processing Record 47 of Set 11 | tangalle
# Processing Record 48 of Set 11 | shimoda
# Processing Record 49 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 0 of Set 12 | tobruk
# Processing Record 1 of Set 12 | trairi
# Processing Record 2 of Set 12 | malmberget
# Processing Record 3 of Set 12 | monte carmelo
# Processing Record 4 of Set 12 | port shepstone
# Processing Record 5 of Set 12 | maumere
# Processing Record 6 of Set 12 | koupela
# Processing Record 7 of Set 12 | huazhou
# Processing Record 8 of Set 12 | brewton
# Processing Record 9 of Set 12 | itaueira
# Processing Record 10 of Set 12 | vizinga
# Processing Record 11 of Set 12 | nukunonu
# City not found. Skipping...
# Processing Record 12 of Set 12 | yen bai
# Processing Record 13 of Set 12 | fort st. john
# Processing Record 14 of Set 12 | mejit
# Processing Record 15 of Set 12 | axim
# Processing Record 16 of Set 12 | jayapura
# Processing Record 17 of Set 12 | kirs
# Processing Record 18 of Set 12 | quibala
# Processing Record 19 of Set 12 | traiguen
# Processing Record 20 of Set 12 | kangding
# Processing Record 21 of Set 12 | hailun
# Processing Record 22 of Set 12 | sirte
# Processing Record 23 of Set 12 | semey
# Processing Record 24 of Set 12 | rupert
# Processing Record 25 of Set 12 | tellicherry
# Processing Record 26 of Set 12 | hyesan
# Processing Record 27 of Set 12 | katsuura
# Processing Record 28 of Set 12 | kasongo-lunda
# Processing Record 29 of Set 12 | alesund
# Processing Record 30 of Set 12 | itoman
# Processing Record 31 of Set 12 | el calafate
# Processing Record 32 of Set 12 | elliot
# Processing Record 33 of Set 12 | colonia
# Processing Record 34 of Set 12 | el rama
# Processing Record 35 of Set 12 | kostyantynivka
# Processing Record 36 of Set 12 | berdigestyakh
# Processing Record 37 of Set 12 | san julian
# Processing Record 38 of Set 12 | nola
# Processing Record 39 of Set 12 | dalcahue
# Processing Record 40 of Set 12 | mauganj
# Processing Record 41 of Set 12 | fannuj
# City not found. Skipping...
# Processing Record 42 of Set 12 | tingi
# Processing Record 43 of Set 12 | tazacorte
# Processing Record 44 of Set 12 | ebaye
# Processing Record 45 of Set 12 | tanki leendert
# City not found. Skipping...
# Processing Record 46 of Set 12 | khabarovsk
# Processing Record 47 of Set 12 | port douglas
# Processing Record 48 of Set 12 | port saint john's
# Processing Record 49 of Set 12 | mahdia
# Processing Record 0 of Set 13 | saudarkrokur
# Processing Record 1 of Set 13 | sheopur
# Processing Record 2 of Set 13 | gebeit
# Processing Record 3 of Set 13 | lethem
# Processing Record 4 of Set 13 | hami
# Processing Record 5 of Set 13 | pokhara
# Processing Record 6 of Set 13 | duba
# Processing Record 7 of Set 13 | walvis bay
# Processing Record 8 of Set 13 | dammam
# Processing Record 9 of Set 13 | xilin hot
# Processing Record 10 of Set 13 | darovskoy
# Processing Record 11 of Set 13 | fortaleza
# Processing Record 12 of Set 13 | sparti
# Processing Record 13 of Set 13 | south tamworth
# Processing Record 14 of Set 13 | istgah-e rah ahan-e garmsar
# Processing Record 15 of Set 13 | bozhou
# Processing Record 16 of Set 13 | ayang-ni
# Processing Record 17 of Set 13 | popondetta
# Processing Record 18 of Set 13 | ceeldheer
# Processing Record 19 of Set 13 | kruisfontein
# Processing Record 20 of Set 13 | sambava
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
#city_data_df.head(10)

# Show Record Count
#city_data_df.to_csv(output_data, index_label="City_ID")
city_data_df.count()
# Out:
# City          592
# Lat           592
# Lng           592
# Max Temp      592
# Humidity      592
# Cloudiness    592
# Wind Speed    592
# Country       592
# Date          592
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        i-n-salah  27.1935    2.4607     83.19        28           0
# 1           albany  42.6001  -73.9662     57.81        93         100
# 2     invercargill -46.4000  168.3500     47.01        79         100
# 3          dudinka  69.4058   86.1778     25.63        89         100
# 4  remire-montjoly   4.9167  -52.2667     80.64        89           0
#
#    Wind Speed Country        Date
# 0       25.03      DZ  1696035890
# 1        1.16      US  1696035848
# 2       21.00      NZ  1696035890
# 3       19.75      RU  1696035890
# 4        3.44      GF  1696035890

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              i-n-salah  27.1935    2.4607     83.19        28           0
# 1                 albany  42.6001  -73.9662     57.81        93         100
# 2           invercargill -46.4000  168.3500     47.01        79         100
# 3                dudinka  69.4058   86.1778     25.63        89         100
# 4        remire-montjoly   4.9167  -52.2667     80.64        89           0
#
#          Wind Speed Country        Date
# City_ID
# 0             25.03      DZ  1696035890
# 1              1.16      US  1696035848
# 2             21.00      NZ  1696035890
# 3             19.75      RU  1696035890
# 4              3.44      GF  1696035890

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temp = city_data_df["Max Temp"]
plt.scatter(lats,
            max_temp,
            edgecolor="black",linewidth=1,marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" %time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lats = city_data_df["Lat"]
humidity = city_data_df["Humidity"]
plt.scatter(lats,
            humidity,
            edgecolor="black",linewidth=1,marker="o")
# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" %time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
lats = city_data_df["Lat"]
cloudiness = city_data_df["Cloudiness"]
plt.scatter(lats,
            cloudiness,
            edgecolor="black",linewidth=1,marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness(%s)" %time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
lats = city_data_df["Lat"]
windspeed = city_data_df["Wind Speed"]
plt.scatter(lats,
            windspeed,
            edgecolor="black",linewidth=1,marker="o")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" %time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Windspeed mph")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,titles,text_coordinates):
    
    #Run regression on southern hemisphere
    (slope, intercept, rvalue,pvalue,stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    #Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=13, color="blue")
    plt.xlabel("Latitude")
    plt.ylabel(y_values.name)
    print(f"The r_squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hem_df = city_data_df.loc[(city_data_df["Lat"] >=0)]


# Display sample data
northern_hem_df.head()
# Out:
#                     City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              i-n-salah  27.1935   2.4607     83.19        28           0
# 1                 albany  42.6001 -73.9662     57.81        93         100
# 3                dudinka  69.4058  86.1778     25.63        89         100
# 4        remire-montjoly   4.9167 -52.2667     80.64        89           0
# 6              ilulissat  69.2167 -51.1000     33.82        80         100
#
#          Wind Speed Country        Date
# City_ID
# 0             25.03      DZ  1696035890
# 1              1.16      US  1696035848
# 3             19.75      RU  1696035890
# 4              3.44      GF  1696035890
# 6              0.00      GL  1696035890

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hem_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hem_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         invercargill -46.4000  168.3500     47.01        79         100
# 5            adamstown -25.0660 -130.1015     69.17        84           8
# 7           rio grande -32.0350  -52.0986     60.94        93         100
# 8        port mathurin -19.6833   63.4167     73.74        63         100
# 10            corbelia -24.7989  -53.3067     66.85        78          84
#
#          Wind Speed Country        Date
# City_ID
# 2             21.00      NZ  1696035890
# 5             23.22      PN  1696035890
# 7              7.58      BR  1696035727
# 8             17.58      MU  1696035890
# 10             4.56      BR  1696035697

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hem_df ["Lat"]
y_values =  northern_hem_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r_squared is: 0.7248793048487818

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hem_df ["Lat"]
y_values = southern_hem_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r_squared is: 0.5654033535766384

# %% [markdown]
# here the relation is a better then the last cell  and direct realtion on  the graph shows the line is going staright up in hemspher close to 1

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hem_df ["Lat"]
y_values = northern_hem_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r_squared is: 0.007637514277233235

# %%
# Southern Hemisphere
x_values = southern_hem_df ["Lat"]
y_values = southern_hem_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-50,15))
# Out:
# The r_squared is: 0.007728699254212335

# %% [markdown]
# here the relation is negative and inverse as the graph shows the line lying flat and as well we vcan see theh valye of y closer to 0mratgher then 1

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hem_df ["Lat"]
y_values = northern_hem_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,50))
# Out:
# The r_squared is: 0.005027017226022929

# %%
# Southern Hemisphere
x_values = southern_hem_df ["Lat"]
y_values = southern_hem_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r_squared is: 0.020972828418657153

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hem_df ["Lat"]
y_values = northern_hem_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (40,22))
# Out:
# The r_squared is: 0.004594970783857643

# %%
# Southern Hemisphere
x_values = southern_hem_df ["Lat"]
y_values = southern_hem_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Windspeed', (-30,30))
# Out:
# The r_squared is: 0.03385838155087347

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
here the relation is negative and inverse as the graph shows the line lying flat and as well we vcan see theh valye of y closer to 0mratgher then 1
